# %%
import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd

# %%
df=pd.read_csv('user-list.csv')

# %%
df.head()
# Out:
#   Course_Code   Student_Name                         github_link    remark
# 0    JOUR2106     Angie Chan         https://github.com/angiecwl  Enrolled
# 1    JOUR2106   CHEN Fang-Yi       https://github.com/FangFangYC  Enrolled
# 2    JOUR2106  Cheung Yan Yi      https://github.com/CheungYanYi  Enrolled
# 3    JOUR2106    ZHAO Minzhu  https://github.com/MindyZHAOMinzhu  Enrolled
# 4    JOUR2106     Holly Chik        https://github.com/hollychik  Enrolled

# %%
namelist=[]
for name in df['github_link']:
    namelist.append(name)

# %%
namelist
# Out:
# ['https://github.com/angiecwl',
#  'https://github.com/FangFangYC',
#  'https://github.com/CheungYanYi',
#  'https://github.com/MindyZHAOMinzhu',
#  'https://github.com/hollychik',
#  'https://github.com/Felicity2724',
#  'https://github.com/ghans19',
#  'https://github.com/rayliurui',
#  'https://github.com/ericachinn',
#  'https://github.com/Midorillusion',
#  'https://github.com/tiffanynys',
#  'https://github.com/SUN08042HanYue',
#  'https://github.com/JimmyDingyiming',
#  'https://github.com/Ly-Iris',
#  'https://github.com/WindyLI75',
#  'https://github.com/anakasuji',
#  'https://github.com/sinyungli',
#  'https://github.com/dragonmasterhk',
#  'https://github.com/minhanhngg',
#  'https://github.com/majormoke',
#  'https://github.com/zoyazhao1996',
#  'https://github.com/ivywang958',
#  'https://github.com/Lewis2019',
#  'https://github.com/tarzankuang',
#  'https://github.com/hupili']

# %%
#find the number of rects
import datetime
def dayofyear():
    date1 = datetime.date(year=int(2019),month=int(1),day=int(7)) #the day you want to start
    date2 = datetime.date(year=int(2018),month=5,day=20) #first day of rects
    return (date1-date2).days+1

# %%
day = dayofyear()

# %%
activities=[]

for url in namelist:
    r=requests.get(url).text
    data=BeautifulSoup(r,"html.parser")
    information=data.find_all('rect')
    for j in range(int(day),len(information)): #start from Jan 7 2019
        activity={}
        activity['url'] = url
        activity['data-date'] = information[j]['data-date']
        activity['data-count'] = information[j]['data-count']
        activities.append(activity)

# %%
#activities

# %%
df2 = pd.DataFrame(activities)

# %%
df2.head()
# Out:
#   data-count   data-date                          url
# 0          0  2019-01-08  https://github.com/angiecwl
# 1          0  2019-01-09  https://github.com/angiecwl
# 2          0  2019-01-10  https://github.com/angiecwl
# 3          0  2019-01-11  https://github.com/angiecwl
# 4          0  2019-01-12  https://github.com/angiecwl

# %%
#data-count is not number but string
df3 = df2.groupby('url')['data-count'].agg('sum').reset_index()
df3
# Out:
#                                    url  \
# 0       https://github.com/CheungYanYi
# 1        https://github.com/FangFangYC
# 2      https://github.com/Felicity2724
# 3   https://github.com/JimmyDingyiming
# 4         https://github.com/Lewis2019
# 5           https://github.com/Ly-Iris
# 6     https://github.com/Midorillusion
# 7   https://github.com/MindyZHAOMinzhu
# 8    https://github.com/SUN08042HanYue
# 9         https://github.com/WindyLI75
# 10        https://github.com/anakasuji
# 11         https://github.com/angiecwl
# 12   https://github.com/dragonmasterhk
# 13       https://github.com/ericachinn
# 14          https://github.com/ghans19
# 15        https://github.com/hollychik
# 16           https://github.com/hupili
# 17       https://github.com/ivywang958
# 18        https://github.com/majormoke
# 19       https://github.com/minhanhngg
# 20        https://github.com/rayliurui
# 21        https://github.com/sinyungli
# 22      https://github.com/tarzankuang
# 23       https://github.com/tiffanynys
# 24     https://github.com/zoyazhao1996
#
#                                            data-count
# 0   0000000000000000000710001000000000000000000000...
# 1   0000000000000000001300000010010000000000000000...
# 2   0000000000000000001403180010000000000000000000...
# 3   0000000000000000001100031000000000000000000000...
# 4   0000001000000000013000000000000000000000000000...
# 5   0000000000000000001300001848000000000000100000...
# 6   0000000000000000008000002000000000000000000000...
# 7   0000000000000000002700006210000000000000000000...
# 8   0000000000000000004000300000000001001000000000...
# 9   0000000000000000006000240000000000000000000000...
# 10  0000000000000000008000000600000000000000000000...
# 11  0000000000000000009000000600000000000000000000...
# 12  0000000000000000001100000040000000000000000000...
# 13  0000000000000000002200000200000000000000000000...
# 14  0000000000000000000000203200000000001510100000...
# 15  0000000000000000001800020054000000000000000000...
# 16  0510010200022010001103325000000000042002020003...
# 17  1000000000000000000000001100000000011350000010...
# 18  0000000000000000006000000000000000000000000000...
# 19  0000000000000000001301100500000000010000000000...
# 20  0000000000000000006000009000000000000000000000...
# 21  0000000000000000000002000000000000000000000000...
# 22  0000000000000000019000000000000000000100000000...
# 23  0000000000000000002500004000000000000000000000...
# 24  0000000000000000001400011000000000000000000000...

# %%
df2['data-count'] = pd.to_numeric(df2['data-count'])
df3 = df2.groupby('url')['data-count'].agg('sum').reset_index()

# %%
df3.rename(columns={'url':'github_link'}, inplace=True)

# %%
#merge two df into one, they must at have one sharing column
df4 = pd.merge(df,df3,how='left',on='github_link')

# %%
df5 = df4.sort_values(by=['data-count'],ascending=False)

# %%
def get_id(x):
    return x.split('https://github.com/')[-1]

# %%
df5['github_id']=df['github_link'].apply(get_id)

# %%
df5
# Out:
#    Course_Code         Student_Name                         github_link  \
# 24    JOUR2106              Hu Pili           https://github.com/hupili
# 5     JOUR2106          DONG Xinyue     https://github.com/Felicity2724
# 3     JOUR2106          ZHAO Minzhu  https://github.com/MindyZHAOMinzhu
# 4     JOUR2106           Holly Chik        https://github.com/hollychik
# 21    JOUR2106           Wang Ziwei       https://github.com/ivywang958
# 7     JOUR2106              Ray Liu        https://github.com/rayliurui
# 13    JOUR2106               LI Yun          https://github.com/Ly-Iris
# 6     JOUR2106       Gursimran Hans          https://github.com/ghans19
# 14    JOUR2106            Li Yuquan        https://github.com/WindyLI75
# 10    JOUR2106           NG Yee Sin       https://github.com/tiffanynys
# 20    JOUR2106            Zhao Zoya     https://github.com/zoyazhao1996
# 8     JOUR2106    Chin Ho Nam Erica       https://github.com/ericachinn
# 18    JOUR2106  Nguyen Thi Minh Anh       https://github.com/minhanhngg
# 17    JOUR2106          Liu Pei Lin   https://github.com/dragonmasterhk
# 12    JOUR2106          Yiming Ding  https://github.com/JimmyDingyiming
# 1     JOUR2106         CHEN Fang-Yi       https://github.com/FangFangYC
# 0     JOUR2106           Angie Chan         https://github.com/angiecwl
# 15    JOUR2106       Akane Nakasuji        https://github.com/anakasuji
# 23    JOUR2108      Kuang Tianzheng      https://github.com/tarzankuang
# 11    JOUR2106          SUN Han Yue   https://github.com/SUN08042HanYue
# 9     JOUR2106            GE XINRAN    https://github.com/Midorillusion
# 2     JOUR2106        Cheung Yan Yi      https://github.com/CheungYanYi
# 19    JOUR2106             MO Kexin        https://github.com/majormoke
# 22    JOUR2107           Chen Lewei        https://github.com/Lewis2019
# 16    JOUR2106          Li Sin Yung        https://github.com/sinyungli
#
#       remark  data-count        github_id
# 24  Lecturer         119           hupili
# 5   Enrolled          91     Felicity2724
# 3   Enrolled          58  MindyZHAOMinzhu
# 4   Enrolled          58        hollychik
# 21    Helper          57       ivywang958
# 7   Enrolled          52        rayliurui
# 13  Enrolled          45          Ly-Iris
# 6   Enrolled          40          ghans19
# 14  Enrolled          31        WindyLI75
# 10  Enrolled          30       tiffanynys
# 20     Audit          25     zoyazhao1996
# 8   Enrolled          24       ericachinn
# 18  Enrolled          21       minhanhngg
# 17  Enrolled          18   dragonmasterhk
# 12  Enrolled          17  JimmyDingyiming
# 1   Enrolled          16       FangFangYC
# 0   Enrolled          16         angiecwl
# 15  Enrolled          14        anakasuji
# 23    Helper          12      tarzankuang
# 11  Enrolled          11   SUN08042HanYue
# 9   Enrolled          10    Midorillusion
# 2   Enrolled           9      CheungYanYi
# 19     Audit           6        majormoke
# 22    Helper           5        Lewis2019
# 16  Enrolled           2        sinyungli

# %%
df5.to_csv('../data/activity_counts.csv', index=None)

# %%
len(df2)
# Out:
# 3350

# %%
df2
# Out:
#       data-count   data-date                          url
# 0              0  2019-01-08  https://github.com/angiecwl
# 1              0  2019-01-09  https://github.com/angiecwl
# 2              0  2019-01-10  https://github.com/angiecwl
# 3              0  2019-01-11  https://github.com/angiecwl
# 4              0  2019-01-12  https://github.com/angiecwl
# 5              0  2019-01-13  https://github.com/angiecwl
# 6              0  2019-01-14  https://github.com/angiecwl
# 7              0  2019-01-15  https://github.com/angiecwl
# 8              0  2019-01-16  https://github.com/angiecwl
# 9              0  2019-01-17  https://github.com/angiecwl
# 10             0  2019-01-18  https://github.com/angiecwl
# 11             0  2019-01-19  https://github.com/angiecwl
